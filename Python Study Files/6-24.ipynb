# %%
# (기본 매개 변수, 가변 매개 변수)

def oz(n = 3, *values):
  for i in range(n):
    for value in values:
      print(value)
    print()

oz("기본 매개변수 다음에", "가변 매개변수를", "넣을 수 있을까요?")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1766408145.py in <cell line: 0>()
#       7     print()
#       8
# ----> 9 oz("기본 매개변수 다음에", "가변 매개변수를", "넣을 수 있을까요?")
#
# /tmp/ipython-input-1766408145.py in oz(n, *values)
#       2
#       3 def oz(n=3, *values):
# ----> 4   for i in range(n):
#       5     for value in values:
#       6       print(value)
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
# (가변 매개 변수, 가본 매개 변수)
def oz(*values, n = 3):
  for i in range(n):
    for value in values:
      print(value)
    print()

oz("기본 매개변수 다음에", "가변 매개변수를", "넣을 수 있을까요?", 10)
# Out:
# 기본 매개변수 다음에
# 가변 매개변수를
# 넣을 수 있을까요?
# 10
#
# 기본 매개변수 다음에
# 가변 매개변수를
# 넣을 수 있을까요?
# 10
#
# 기본 매개변수 다음에
# 가변 매개변수를
# 넣을 수 있을까요?
# 10

# %%
# end = \n
list = ['안', '녕', '하', '세', '요']
for i in list:
  print(i)
# Out:
# 안
# 녕
# 하
# 세
# 요

# %%
list = ['안', '녕', '하', '세', '요']
for i in list:
  print(i, end = '')
# Out:
# 안녕하세요

# %%
# 직육면체를 부피를 구하는 코드를 작성해보자 : 가로 : x, 세로 : y, 높이 : h
def oz(x, y = 20, h = 10):
  print(x * y * h)

# x식별자에 매개변수 10을 넣은 경우
oz(10)
# x식별자에 10을 넣고 y = 10이라는 키워드 매개변수를 이용한 경우
oz(10, y=10)
# 모든 매개변수를 키워드 매개변수로 넣는 경우
oz(x=5, y=5, h=5)
# Out:
# 2000
# 1000
# 125
