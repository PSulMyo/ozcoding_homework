# %%
num = 10
print(type(num))

num = '10'
print(type(num))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# 직육면체 부피를 구하는 함수
def oz(x : int, y : int, h : int) -> int:
  # type : (int, int, int)
  return x * y * h

oz(10,10,10)
# Out:
# 1000

# %%
# 3.9버전과 3.9미만 버전의 타입 이노베이션 표현 방식이 차이가 있습니다.
# 현재 코드는 3.9이상 버전의 방식으로 작성되었습니다.
# 변수 타입 이노베이션 사용법

my_dog : str = 'hunt'
my_dog_age : int = 7

dogs : list[str] = ['닥스훈트', '시바견', '웰시코기', '이탈리안그레이하운드']

dogs : dict[str, int] = {
    '닥스훈트' : 7,
    '시바견' : 5,
    '웰시코기' : 6,
    '이탈리안그레이하운드' : 3,
}

print(my_dog)
# Out:
# hunt

# %%
def hunt(name : str) -> str:
  return name[0]

def hunt_info(name : str, age : int = 7) -> str:
  return name + str(age)

def hunt_happy_time(name : str) -> None:
  print('간식줄께' + name)

def hunt_bow(message : str, times : int = 10) -> list[str]:
  return [message] * times
