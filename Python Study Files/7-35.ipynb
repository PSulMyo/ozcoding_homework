# %% [markdown]
# [ 예외객체 ]
#  - Exception을 사용하면 예외의 종류에 대해 알 수 있습니다.

# %%
try:
  x, y = map(int, input('밑변과 높이를 입력해주세요.').split(','))
  print(f'삼각형의 넓이는 {x * y / 2}입니다.')
except:
  print('정수로 입력하지 않아 계산이 불가합니다.')
# Out:
# 밑변과 높이를 입력해주세요.2
# 정수로 입력하지 않아 계산이 불가합니다.

# %%
try:
  x, y = map(int, input('밑변과 높이를 입력해주세요.').split(','))
  print(f'삼각형의 넓이는 {x * y / 2}입니다.')
except Exception as exception:
  print('type(exception) : ', type(exception))
  print('exception : ', exception)
# Out:
# 밑변과 높이를 입력해주세요.sd
# type(exception) :  <class 'ValueError'>
# exception :  invalid literal for int() with base 10: 'sd'

# %% [markdown]
# 예외객체 자료형은 Value Error이고
# 내용은 invaild literal for int() with base 10: '3cm' 입니다.
#
# [ 예외 구분하기 ]
# 여러 가지 예외가 발생하는 상황을 기분지어 대비하기 위함.

# %%
numbers = [23, 11, 7, 4, 12]

try:
  number_input = int(input('찾고싶은 값의 위치를 입력해주세요.'))
  print(f'{number_input}번째 요소 : {numbers[number_input]}')
except Exception as exception:
  print('type(exception) : ', type(exception))
  print('exception : ', exception)
# Out:
# 찾고싶은 값의 위치를 입력해주세요.3
# 3번째 요소 : 4

# %% [markdown]
# [ except: list index out of range ]
# 와 같은 에러를 구분하고 처리할 수 있는 기능을 파이썬에서 제공합니다.
#
# try:
# __예외가 발생할 가능성이 있는 구문
# except 예외 a:
# __예외 a가 발생했을 때 실행할 구문
# except 예외 b:
# __예외 b가 발생했을 때 실행할 구문
# except 예외 c:
# __예외 c가 발생했을 때 실행할 구문

# %%
numbers = [23, 11, 7, 4, 12]

try:
  number_input = int(input('찾고싶은 값의 위치를 입력해주세요.'))
  print(f'{number_input}번째 요소 : {numbers[number_input]}')
except ValueError:
  print('정수로 입력해주세요')
except IndexError:
  print('리스트의 범위를 벗어났습니다. 입력값을 다시 확인해주세요.')
# Out:
# 찾고싶은 값의 위치를 입력해주세요.9
# 리스트의 범위를 벗어났습니다. 입력값을 다시 확인해주세요.

# %% [markdown]
# [ 예외 구분 구문과 예외 객체 ]
# as 키워드를 이용해 as exception을 사용할 수 있음

# %%
numbers = [23, 11, 7, 4, 12]

try:
  number_input = int(input('찾고싶은 값의 위치를 입력해주세요.'))
  print(f'{number_input}번째 요소 : {numbers[number_input]}')
except ValueError as exception:
  print('정수로 입력해주세요')
  print('Exception : ', exception)
except IndexError as exception:
  print('리스트의 범위를 벗어났습니다. 입력값을 다시 확인해주세요.')
  print('Exception : ', exception)
# Out:
# 찾고싶은 값의 위치를 입력해주세요.oz
# 정수로 입력해주세요
# Exception :  invalid literal for int() with base 10: 'oz'
