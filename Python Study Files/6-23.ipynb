# %%
def oz(value, n=2):
  for i in range(n):
    print(value)

oz('일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.', n = 10)
# Out:
# 일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.
# 일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.
# 일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.
# 일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.
# 일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.
# 일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.
# 일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.
# 일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.
# 일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.
# 일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.

# %%
# 기본 매개변수 사용에 문제가 있음을 오류 메시지로 보여주고 있습니다.
# 지금부터는 강의를 잠시 멈춰두고 아래 3가지 키워드에 대해서 여러분들이 이해한 방식대로 정리하는 시간을 가져보시기 바랍니다.

# 1. 기본 매개 변수를 역할은 무엇인가요?
# - 미리 기본 값을 지정해두는 것
# 2. 기본 매개 변수를 사용하기 위한 문법은 어떻게 되나요?
# - def 함수(매개변수, 매개변수 = 숫자):
# -   코드
# 3. 기본 매개 변수의 사용 시 제약 조건에 대해 설명해주세요.
# - 항상 일반 매개변수 뒤에 와야 한다.
# - 왠만하면 변경 가능한 객체(mutable object)를 기본값으로 사용하지 않기
