# %% [markdown]
#  - isinstance() : 첫 번째 매개변수에는 인스턴스(객체),두 번째 매개변수에는 클래스를 입력해주면
#  두 번째 매개변수로 입력한 클래스 기반으로 인스턴스가 생성되었는지 True, False로 반환해줍니다.
#
# 예제 코드를 통해 확인해보겠습니다.

# %%
class Student:
  def __init__(self):
    pass

student = Student()

print('isinstance(student, Student) : ', isinstance(student, Student))
# Out:
# isinstance(student, Student) :  True

# %% [markdown]
# Student 클래스로 만든 클래스가 student이기 때문에 True가 출력된걸 확인할 수 있습니다.
# 지금부터는 isinstance() 함수를 이용해 여러개의 클래스에서 생성된 인스턴스를 구분해 처리하는 코드를 작성해보겠습니다.

# %%
class Python:
  def python(self):
    print('파이썬을 수강중입니다.')

class Java:
  def java(self):
    print('자바를 수강중입니다.')

programming_subjects = [Python(), Python(), Python(), Java(), Python()]

for subject in programming_subjects:
  if isinstance(subject, Python):
    subject.python()
  elif isinstance(subject, Java):
    subject.java()
# Out:
# 파이썬을 수강중입니다.
# 파이썬을 수강중입니다.
# 파이썬을 수강중입니다.
# 자바를 수강중입니다.
# 파이썬을 수강중입니다.

# %%
# 예제

class Student:
  def __init__(self):
    programming_subjects

# Student()는 클래스 명과 동일한 생성자 함수
# student는 Student 클래스로 생성된 객체 즉 인스턴스를 말함
student = Student()

student.

print('isinstance(student, Student) : ', isinstance(student, Student)) # 인스턴트, 클래스

# %% [markdown]
# ```__이름__``` 이런 형태의 네이밍을 가집니다.
# ```__str__()``` 이란 이름으로 기존 to_string 함수의 이름을 대체 해보겠습니다.
# 참고로, ```__str__()``` 로 전의하게 되면 str()만 입력해도 기존 방식과 다르게 자동을 호출됩니다.
# 그래서 기존에 있는 함수 호출 부분인 코드를
# ```print(student.to_string())```
# 이렇게 변경해서 실행할 수 있습니다.
# ```print(str(student))```

# %%
# 기존코드
# __ 은 언더바('_') 두개 입니다.
class CreateOzStudent:
  def __init__(self,name, python, database, django, AWS):
    self.name = name
    self.python = python
    self.database = database
    self.django = django
    self.AWS = AWS

  def get_sum(self):
    return self.python + self.database + self.django + self.AWS

  def get_avg(self):
    return self.get_sum() / 4

  def to_string(self):
    return f'{self.name}\t{self.get_sum()}\t{self.get_avg()}'

# 데이터 입력
oz_students = [
  CreateOzStudent('백현우', 4, 3, 3, 2), # CreateOzStudent() 생성자를 이용해 리스트 안에 데이터 생성
  CreateOzStudent('홍혜인', 4, 5, 2, 4),
  CreateOzStudent('윤은성', 3, 4, 4, 1),
  CreateOzStudent('홍수철', 2, 3, 1, 5)
]

print('이름', '총점', '평균', sep='\t')
for student in oz_students:
  print(student.to_string())

# %%
# __str__ 이름 사용
# __ 은 언더바('_') 두개 입니다.
class CreateOzStudent:
  def __init__(self,name, python, database, django, AWS):
    self.name = name
    self.python = python
    self.database = database
    self.django = django
    self.AWS = AWS

  def get_sum(self):
    return self.python + self.database + self.django + self.AWS

  def get_avg(self):
    return self.get_sum() / 4

  def __str__(self):
    return f'{self.name}\t{self.get_sum()}\t{self.get_avg()}'

  # def __eq__(self):
  #   return 뭐시기

# 데이터 입력
oz_students = [
  CreateOzStudent('백현우', 4, 3, 3, 2), # CreateOzStudent() 생성자를 이용해 리스트 안에 데이터 생성
  CreateOzStudent('홍혜인', 4, 5, 2, 4),
  CreateOzStudent('윤은성', 3, 4, 4, 1),
  CreateOzStudent('홍수철', 2, 3, 1, 5)
]

print('이름', '총점', '평균', sep='\t')
for student in oz_students:
  print(str(student))
  # print(student == student_2)
# Out:
# 이름	총점	평균
# 백현우	12	3.0
# 홍혜인	15	3.75
# 윤은성	12	3.0
# 홍수철	11	2.75

# %% [markdown]
# ```__str__``` 외에도 다양한 이름들이 있습니다.
# 예를 하나 더 들어보자면 ```__eq__``` 로 이름을 사용한 경우
# 실행 방법은 ' == ' 이용해서 사용할 수 있습니다.
