# %%
# 반복문을 이용한 팩토리얼 구현 코드
# 곱하기 연산이 진행되기 때문에 output의 초기값은 1입니다. 더하기 연산이 진행되는 경우는 0으로 초기값을 설정합니다.

def oz_factorial(n):
  output = 1
  for i in range(1, n + 1):
    output *= i
  return output

n = int(input('구하고자하는 팩토리얼의 수를 입력해주세요.'))
print(f'{n}의 결과는 {oz_factorial(n)}입니다.')
# Out:
# 구하고자하는 팩토리얼의 수를 입력해주세요.5
# 5의 결과는 120입니다.

# %%
# 재귀함수를 이용한 팩토리얼 구현 코드
def oz_factorial(n):
  if n == 0:
    return 1
  else:
    return n * oz_factorial(n-1)

n = int(input('구하고자하는 팩토리얼의 수를 입력해주세요.'))
print(f'{n}의 결과는 {oz_factorial(n)}입니다.')
# Out:
# 구하고자하는 팩토리얼의 수를 입력해주세요.5
# 5의 결과는 120입니다.

# %%
# 피보나치 수열 함수 실행 시 계산되는 횟수를 파악하기 위한
# 파이썬은 함수 내부에서 함수 밖에 있는 변수를 사용할 수 없습니다.
# 그래서 global 키워드 함수를 이용해 함수 내부에서 함수 밖에 있는 변수를 사용할 수 있도록 만들어 줍니다.

count = 0

def oz_fibo(n):
  print(f'피보나치 수열 {n}을 구하는 중입니다.')
  global count
  count += 1

  if n == 1:
    return 1
  if n == 2:
    return 1
  else:
    return oz_fibo(n - 1) + oz_fibo(n - 2)

n = int(input('구하고자하는 파보나치의 수열의 수를 입력해주세요.'))
oz_fibo(n)
print(f'파보나치 수열 {n}을 구하기 위해 계산된 횟수는 {count}입니다.')
# Out:
# 구하고자하는 파보나치의 수열의 수를 입력해주세요.5
# 피보나치 수열 5을 구하는 중입니다.
# 피보나치 수열 4을 구하는 중입니다.
# 피보나치 수열 3을 구하는 중입니다.
# 피보나치 수열 2을 구하는 중입니다.
# 피보나치 수열 1을 구하는 중입니다.
# 피보나치 수열 2을 구하는 중입니다.
# 피보나치 수열 3을 구하는 중입니다.
# 피보나치 수열 2을 구하는 중입니다.
# 피보나치 수열 1을 구하는 중입니다.
# 파보나치 수열 5을 구하기 위해 계산된 횟수는 9입니다.

# %%
# 코드 핵심 설명
# - 초기 값으로 설정했던 첫번째와 두번째 결과값을 memo 변수에 dict형 자료형을 넣어 저장합니다.
# - oz_fibo() 함수 실행 시 memo 변수에 계산할 파보니치 수열의 결과값이 있는지를 확인합니다.
# 있다면 계산을 하지 않고 이미 계산되어 저장된 결과값을 이용합니다.
# - 만일 결과값이 저장되어 있지 않은 경우 계산을 합니다. 그리고 계산된 결과값은 다음 계산에서 활용할 수 있도록 memo에 저장합니다.

memo = {
    1: 1,
    2: 1
}

count = 0

def oz_fibo(n):
  print(f'피보나치 수열 {n}을 구하는 중입니다.')
  global count
  count += 1

  if n in memo:
    return memo[n]
  else:
    output = oz_fibo(n - 1) + oz_fibo(n - 2)
    memo[n] = output
    return output

n = int(input('구하고자하는 파보나치의 수열의 수를 입력해주세요.'))
oz_fibo(n)
print(f'파보나치 수열 {n}을 구하기 위해 계산된 횟수는 {count}입니다.')
# Out:
# 구하고자하는 파보나치의 수열의 수를 입력해주세요.10
# 피보나치 수열 10을 구하는 중입니다.
# 피보나치 수열 9을 구하는 중입니다.
# 피보나치 수열 8을 구하는 중입니다.
# 피보나치 수열 7을 구하는 중입니다.
# 피보나치 수열 6을 구하는 중입니다.
# 피보나치 수열 5을 구하는 중입니다.
# 피보나치 수열 4을 구하는 중입니다.
# 피보나치 수열 3을 구하는 중입니다.
# 피보나치 수열 2을 구하는 중입니다.
# 피보나치 수열 1을 구하는 중입니다.
# 피보나치 수열 2을 구하는 중입니다.
# 피보나치 수열 3을 구하는 중입니다.
# 피보나치 수열 4을 구하는 중입니다.
# 피보나치 수열 5을 구하는 중입니다.
# 피보나치 수열 6을 구하는 중입니다.
# 피보나치 수열 7을 구하는 중입니다.
# 피보나치 수열 8을 구하는 중입니다.
# 파보나치 수열 10을 구하기 위해 계산된 횟수는 17입니다.

# %%
# 지금부터는 강의를 잠시 멈춰두고 아래 3가지 키워드에 대해서 여러분들이 이해한 방식대로 정리하는 시간을 가져보시기 바랍니다.
# - 재귀함수에 대한 설명과 장단점을 알려주세요.
# ㄴ 재귀 조건(Base Case) : 재귀 호출을 멈추는 조건, 이 조건이 없으면 함수가 무한히 자기 자신을 호출하다가 큰 문제가 발생할 수 있음.
# ㄴ 재귀 단계(Recursive Step) : 문제가 해결될 때까지 자기 자신을 더 작은 문제로 나누어 호출하는 부분.
# ㄴ 장점 : 코드의 간결성 및 가독성, 변수의 수를 줄일 수 있다.
# ㄴ 단점 : 스택 오버플로우(Stack Overflow) 발생 위험, 메모리 사용량 증가, 성능 저하 가능성, 코드 이해의 어려움.
# - 재귀함수 사용 시.발생할 수 있는 단점과 해결방법에 대해 알려주세요.
# ㄴ 스택 오버플로우(Stack Overflow) 발생 위험 : 기저 조건(Base Case) 명확히 설명, 반복문(Iterative)으로 변경, 꼬리 재귀 최적화(Tail Recursion Optimization), 재귀 깊이 제한 늘리기(Python)
# ㄴ 성능 및 메모리 오버헤드 : 반복문(Iterative)으로 변경, 메모이제이션(Memoization) / 동적 계획법(Dynamic Programming), 적저한 알고리즘 선택
# ㄴ 코드 이해 및 디버깅의 어려움 : 명확한 정의 및 주석, 재귀 트리(Recursion Tree) 그리기, 디버깅 도구 활용
# - 메모리제이션에 대해 설명해주세요.
# ㄴ 메모이제이션은 시간이 오래 걸리고, 자주 반복되는 계산의 결과를 기억(memo)해두는 기술.
