# %%
# 깂 없이 리턴하는 경우

def oz_return():
  print('파이썬')
  print('재미있엉')
  return
  print('거짓말하네')

oz_return()
# Out:
# 파이썬
# 재미있엉

# %%
# 아무것도 리턴하지 않는 경우

def oz_return():
  return

result = oz_return()
print(result)
# Out:
# None

# %%
bool(None)
# Out:
# False

# %%
result = input('1+1은?')
print(result)
# Out:
# 1+1은?2
# 2

# %%
# input() 함수는 값을 입력받을 수 있게 해주는 기능을 가지고 있는것으로만 생각하고 사용해왔습니다.
# return이라는 개념을 넣어서 이 과정을 설명해볼 수 있을 것 같습니다.

# - input('프롬포트 메시지') 이렇게 사용하면, 괄호 안에 있는 메시지를 화면에 먼저 보여줌. 이걸 '프롬포트' 라고 함.
# - 메시지를 보여준 뒤에 프로그램이 잠시 멈춰 서서 사용자가 키보드로 뭔가를 입력하고 Enter 키를 누르기를 기다림.
# - 사용자가 Enter 키를 누르면, input() 함수는 사용자가 입력한 모든 내용을 하나의 문자열(string)로 묶어서 돌려줌(Return)
# - 돌려주는 이 행위가 Return의 개념과 맞는 부분.
