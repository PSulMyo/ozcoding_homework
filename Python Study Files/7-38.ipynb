# %% [markdown]
# [ 외부모듈 ]
# 파이썬의 장점 중 하나는 다양한 외부모듈입니다.
# 인공지능 분야에서는 텐서플로와 사이킷런, 웹 분야에서 django와 fastapi 등 굉장히 많은 모듈들이 존재하는데요
# 이러한 모듈을 설치하는 방법은 pip install 이라는 명령을 이용합니다.
#
# pip install 모듈 이름
#
# ( Package installer of Python )
# 파이썬 외부모듈 중 정적페이지를 크롤링하거나 스크래핑할때 사용하는 beautifulsoup4 을 설치해서
# 간단하게 사용해보겠습니다.
#
# beautifulsoup4 공홈 : https://www.crummy.com/software/BeautifulSoup/bs4/doc.ko/
#
# [ window ]
# pip install beautifulsoup4
#
# [ mac ]
# pip3 install beautifulsoup4
# brew install beautifulsoup4
#
# [ 기상청 RSS 서비스 ] https://www.weather.go.kr/w/pop/rss-guide.do
#
# RSS(Really Simple Syndication, Rich Site Summary)란 블로그처럼 컨텐츠 업데이트가 자주 일어나는 웹사이트에서,
# 업데이트된 정보를 쉽게 구독자들에게 제공하기 위해 XML을 기초로 만들어진 데이터 형식입니다.
#
# RSS서비스를 이용하면 업데이트된 정보를 찾기 위해 홈페이지에 일일이 방문하지 않아도
# 업데이트 될 때마다 빠르고 편리하게 확인할 수 있습니다.
#
# rss 전국 기상 정보 주소 : https://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnld=108
