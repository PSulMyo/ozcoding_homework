# %%
# 구분오류 예제
print('오류는 아주 사소한 것 부터 발생합니다.')
# Out:
# 오류는 아주 사소한 것 부터 발생합니다.

# %%
# 닫는 괄호를 생략한 경우
print('오류는 아주 사소한 것 부터 발생합니다.'

# SyntaxError : 구분에 문제가 발생해 프로그램이 실행조차 되지 않는 오류
# -> 이런 경우 오류를 해결하지 않으면 프로그램을 실행할 수 없음.
# Out:
#   File "/tmp/ipython-input-603927048.py", line 2
#     print('오류는 아주 사소한 것 부터 발생합니다.'
#                                   ^
# SyntaxError: incomplete input

# %%
# 생략한 괄호 삽입해 구분오류 해결
print('오류는 아주 사소한 것 부터 발생합니다.')
# Out:
# 오류는 아주 사소한 것 부터 발생합니다.

# %%
# 정상 실행
print('오류는 아주 사소한 것 부터 발생합니다.')

# 예외 발생
dogs.append('말티즈')
# Out:
# 오류는 아주 사소한 것 부터 발생합니다.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2010988403.py in <cell line: 0>()
#       3
#       4 # 예외 발생
# ----> 5 dogs.append('말티즈')
#
# NameError: name 'dogs' is not defined

# %%
# 정상 실행
print('오류는 아주 사소한 것 부터 발생합니다.')

# 예외 발생 코드 해결
dogs = ['닥스훈트', '시바견']
dogs.append('말티즈')
print(dogs)
# Out:
# 오류는 아주 사소한 것 부터 발생합니다.
# ['닥스훈트', '시바견', '말티즈']

# %% [markdown]
# [ 기본 예외 처리 ]
# 예외 처리하는 2가지 방법
#  - 조건문을 사용하는 방법
#  - try 구문을 사용하는 방법
# 단, 구문 오류가 발생하는 경우는 예외 처리로 불가하기 때문에 코드 자체를 수정하는 방법으로 해결해야 함.
#
# [ 조건문을 이용한 예외 처리 ]
#  - 조건문을 이용한 예외 처리방법을 기본 예외 처리라고 함.
# 예외가 발생할 수 있는 상황을 파악하는게 우선입니다. 아래 코드를 통해서 발생할 수 있는 예외 상황을 알아보겠습니다.

# %%
x, y = map(int, input('밑변과 높이를 입력해주세요').split(','))

print(f'삼각형의 넓이는 {x * y / 2}입니다.')
# Out:
# 밑변과 높이를 입력해주세요4 8
# 삼각형의 넓이는 16.0입니다.

# %%
# x = 3cm, y = 5cm
x, y = map(int, input('밑변과 높이를 입력해주세요').split(','))

print(f'삼각형의 넓이는 {x * y / 2}입니다.')
# Out:
# 밑변과 높이를 입력해주세요3cm,5cm
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-190037751.py in <cell line: 0>()
#       1 # x = 3cm, y = 5cm
# ----> 2 x, y = map(int, input('밑변과 높이를 입력해주세요').split(','))
#       3
#       4 print(f'삼각형의 넓이는 {x * y / 2}입니다.')
#
# ValueError: invalid literal for int() with base 10: '3cm'

# %%
x, y = input('밑변과 높이를 입력해주세요').split(',')

if x.isdigit() and y.isdigit():
  x, y = int(x), int(y)
  print(f'삼각형의 넓이는 {x * y / 2}입니다.')
else:
  print('정수로 입력하지 않아 계산이 불가합니다.')
# Out:
# 밑변과 높이를 입력해주세요3cm,4cm
# 정수로 입력하지 않아 계산이 불가합니다.
